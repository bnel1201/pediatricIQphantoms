# %%
from pathlib import Path
import pandas as pd
import SimpleITK as sitk
import pydicom
import matplotlib.pyplot as plt

# %% [markdown]
# ## Viewing Images

# %%
# !tree /gpfs_projects/brandon.nelson/RSTs/pediatricIQphantoms -P *_000.dcm | head -n 15
# Out:
# /gpfs_projects/brandon.nelson/RSTs/pediatricIQphantoms
# ├── CTP404
# │   ├── diameter_112mm
# │   │   ├── dose_025
# │   │   │   └── fbp
# │   │   │       └── 112mm_CTP404_000.dcm
# │   │   └── dose_100
# │   │       └── fbp
# │   │           └── 112mm_CTP404_000.dcm
# │   ├── diameter_131mm
# │   │   ├── dose_025
# │   │   │   └── fbp
# │   │   │       └── 131mm_CTP404_000.dcm
# │   │   └── dose_100
# │   │       └── fbp

# %%
from pathlib import Path
import pandas as pd
base_dir = Path('/gpfs_projects/brandon.nelson/RSTs/pediatricIQphantoms')
metadata = pd.read_csv(base_dir / 'metadata.csv')
metadata.file = metadata.file.apply(lambda o: base_dir / o)

# %%
metadata
# Out:
#                  Name  effective diameter [cm]  age [year] pediatric subgroup  \
# 0      11.2 cm CTP404                     11.2    0.083333            newborn
# 1      11.2 cm CTP404                     11.2    0.083333            newborn
# 2      11.2 cm CTP404                     11.2    0.083333            newborn
# 3      11.2 cm CTP404                     11.2    0.083333            newborn
# 4      11.2 cm CTP404                     11.2    0.083333            newborn
# ...               ...                      ...         ...                ...
# 6755  35.0 cm uniform                     35.0   39.000000              adult
# 6756  35.0 cm uniform                     35.0   39.000000              adult
# 6757  35.0 cm uniform                     35.0   39.000000              adult
# 6758  35.0 cm uniform                     35.0   39.000000              adult
# 6759  35.0 cm uniform                     35.0   39.000000              adult
#
#       phantom                     scanner  Dose [%]         recon kernel  \
# 0      CTP404  Siemens Somatom Definition      25.0           fbp    D45
# 1      CTP404  Siemens Somatom Definition      25.0           fbp    D45
# 2      CTP404  Siemens Somatom Definition      25.0           fbp    D45
# 3      CTP404  Siemens Somatom Definition      25.0           fbp    D45
# 4      CTP404  Siemens Somatom Definition      25.0           fbp    D45
# ...       ...                         ...       ...           ...    ...
# 6755  uniform  Siemens Somatom Definition     100.0           fbp    D45
# 6756  uniform  Siemens Somatom Definition     100.0           fbp    D45
# 6757  uniform  Siemens Somatom Definition     100.0           fbp    D45
# 6758  uniform  Siemens Somatom Definition       NaN  ground truth    NaN
# 6759  uniform  Siemens Somatom Definition       NaN    noise free    NaN
#
#       FOV [cm]                                               file  patientid  \
# 0         12.3  /gpfs_projects/brandon.nelson/RSTs/pediatricIQ...        0.0
# 1         12.3  /gpfs_projects/brandon.nelson/RSTs/pediatricIQ...        0.0
# 2         12.3  /gpfs_projects/brandon.nelson/RSTs/pediatricIQ...        0.0
# 3         12.3  /gpfs_projects/brandon.nelson/RSTs/pediatricIQ...        0.0
# 4         12.3  /gpfs_projects/brandon.nelson/RSTs/pediatricIQ...        0.0
# ...        ...                                                ...        ...
# 6755      39.0  /gpfs_projects/brandon.nelson/RSTs/pediatricIQ...       23.0
# 6756      39.0  /gpfs_projects/brandon.nelson/RSTs/pediatricIQ...       23.0
# 6757      39.0  /gpfs_projects/brandon.nelson/RSTs/pediatricIQ...       23.0
# 6758      39.0  /gpfs_projects/brandon.nelson/RSTs/pediatricIQ...       23.0
# 6759      39.0  /gpfs_projects/brandon.nelson/RSTs/pediatricIQ...       23.0
#
#       studyid        series  repeat
# 0           0    simulation       0
# 1           0    simulation       1
# 2           0    simulation       2
# 3           0    simulation       3
# 4           0    simulation       4
# ...       ...           ...     ...
# 6755       93    simulation     197
# 6756       93    simulation     198
# 6757       93    simulation     199
# 6758       94  ground truth       0
# 6759       95    noise free       0
#
# [6760 rows x 15 columns]

# %%
metadata[metadata.phantom=='MITA-LCD']
# Out:
#                   Name  effective diameter [cm]  age [year]  \
# 328   11.2 cm MITA-LCD                     11.2    0.083333
# 329   11.2 cm MITA-LCD                     11.2    0.083333
# 330   11.2 cm MITA-LCD                     11.2    0.083333
# 331   11.2 cm MITA-LCD                     11.2    0.083333
# 332   11.2 cm MITA-LCD                     11.2    0.083333
# ...                ...                      ...         ...
# 3539  35.0 cm MITA-LCD                     35.0   39.000000
# 3540  35.0 cm MITA-LCD                     35.0   39.000000
# 3541  35.0 cm MITA-LCD                     35.0   39.000000
# 3542  35.0 cm MITA-LCD                     35.0   39.000000
# 3543  35.0 cm MITA-LCD                     35.0   39.000000
#
#      pediatric subgroup   phantom                     scanner  Dose [%]  \
# 328             newborn  MITA-LCD  Siemens Somatom Definition      25.0
# 329             newborn  MITA-LCD  Siemens Somatom Definition      25.0
# 330             newborn  MITA-LCD  Siemens Somatom Definition      25.0
# 331             newborn  MITA-LCD  Siemens Somatom Definition      25.0
# 332             newborn  MITA-LCD  Siemens Somatom Definition      25.0
# ...                 ...       ...                         ...       ...
# 3539              adult  MITA-LCD  Siemens Somatom Definition     100.0
# 3540              adult  MITA-LCD  Siemens Somatom Definition     100.0
# 3541              adult  MITA-LCD  Siemens Somatom Definition     100.0
# 3542              adult  MITA-LCD  Siemens Somatom Definition       NaN
# 3543              adult  MITA-LCD  Siemens Somatom Definition       NaN
#
#              recon kernel  FOV [cm]  \
# 328            fbp    D45      12.0
# 329            fbp    D45      12.0
# 330            fbp    D45      12.0
# 331            fbp    D45      12.0
# 332            fbp    D45      12.0
# ...            ...    ...       ...
# 3539           fbp    D45      39.0
# 3540           fbp    D45      39.0
# 3541           fbp    D45      39.0
# 3542  ground truth    NaN      39.0
# 3543    noise free    NaN      39.0
#
#                                                    file  patientid  studyid  \
# 328   /gpfs_projects/brandon.nelson/RSTs/pediatricIQ...        8.0       32
# 329   /gpfs_projects/brandon.nelson/RSTs/pediatricIQ...        8.0       32
# 330   /gpfs_projects/brandon.nelson/RSTs/pediatricIQ...        8.0       32
# 331   /gpfs_projects/brandon.nelson/RSTs/pediatricIQ...        8.0       32
# 332   /gpfs_projects/brandon.nelson/RSTs/pediatricIQ...        8.0       32
# ...                                                 ...        ...      ...
# 3539  /gpfs_projects/brandon.nelson/RSTs/pediatricIQ...       15.0       61
# 3540  /gpfs_projects/brandon.nelson/RSTs/pediatricIQ...       15.0       61
# 3541  /gpfs_projects/brandon.nelson/RSTs/pediatricIQ...       15.0       61
# 3542  /gpfs_projects/brandon.nelson/RSTs/pediatricIQ...       15.0       62
# 3543  /gpfs_projects/brandon.nelson/RSTs/pediatricIQ...       15.0       63
#
#             series  repeat
# 328     simulation       0
# 329     simulation       1
# 330     simulation       2
# 331     simulation       3
# 332     simulation       4
# ...            ...     ...
# 3539    simulation     197
# 3540    simulation     198
# 3541    simulation     199
# 3542  ground truth       0
# 3543    noise free       0
#
# [3216 rows x 15 columns]

# %%
import matplotlib.pyplot as plt
import pydicom
row = metadata[(metadata['Dose [%]']==25) &
               (metadata['phantom'] == 'MITA-LCD') &
               (metadata['recon'] == 'fbp') &
               (metadata['kernel'] == 'D45') &
               (metadata['FOV [cm]'] == 32.0) &
               (metadata['repeat'] == 0)]
dcm_file = row.file.item()
dcm = pydicom.dcmread(dcm_file)
img = dcm.pixel_array + int(dcm.RescaleIntercept)
plt.imshow(img, cmap='gray')
plt.colorbar()
plt.show()
row
# Out:
#                   Name  effective diameter [cm]  age [year]  \
# 2740  29.2 cm MITA-LCD                     29.2        21.0
#
#      pediatric subgroup   phantom                     scanner  Dose [%] recon  \
# 2740         adolescent  MITA-LCD  Siemens Somatom Definition      25.0   fbp
#
#      kernel  FOV [cm]                                               file  \
# 2740    D45      32.0  /gpfs_projects/brandon.nelson/RSTs/pediatricIQ...
#
#       patientid  studyid      series  repeat
# 2740       14.0       56  simulation       0

# %%
from utils import browse_studies
browse_studies(metadata, phantom='CTP404', fov=12.3, dose=100, recon='noise free', kernel='D45', repeat=0, display='soft tissues')

# %%
from utils import study_viewer

# %%
study_viewer(metadata)
# Out:
# interactive(children=(Dropdown(description='phantom', options=('CTP404', 'MITA-LCD', 'uniform'), value='CTP404…

# %% [markdown]
# ## Viewing with Slicer

# %% [markdown]
# Other Viewers
# 1. Radiant (subscription)
# 2. SNAP ITK
# 3. ImageJ

# %% [markdown]
# ## TODO
#
# 1. [X] once simulations are done, add also the noise free simulations to the dataset so both ground truth and noise free are available in the dataset
# 2. zip and upload updated dataset to [Zenodo](https://zenodo.org/records/10064036)
